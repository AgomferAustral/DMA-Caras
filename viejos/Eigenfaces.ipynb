# %% [markdown]
# <a href="https://colab.research.google.com/github/AgomferAustral/DMA-Caras/blob/main/Eigenfaces.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# conexion al Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Cargar las librerias que vamos a utilizar

# %%
import cv2
import math
import numpy as np
import os
import pickle
import random
import sys
import numpy as np
from sklearn.manifold import Isomap
from PIL import Image
from sklearn.decomposition import PCA
from sklearn.manifold import Isomap
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.model_selection import train_test_split
#!pip install --upgrade numpy
#!pip install --upgrade scipy

# %% [markdown]
# # Preprocesamos imagenes
# ## La carpeta de origen se llama Eigenfaces

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# Definicion de ruta de conexion - Origen - Destino imagenes

img_size=(60,60)

ruta_entrada = '/content/drive/MyDrive/Eigenfaces'
ruta_salida = f'/content/drive/MyDrive/Eigenfaces2-{img_size[0]}x{img_size[1]}'


# prompt: verificar si la carpeta en "ruta_salida" existe. Si no existe, crearla

if not os.path.exists(ruta_salida):
  os.makedirs(ruta_salida)

def procesar_archivos_en_carpetas(ruta_principal,ruta_final, imgsize):
  """Recorre las carpetas dentro de la ruta principal y procesa los archivos.

  Args:
    ruta_principal: La ruta de la carpeta principal.
  """

  fraccion = 8


  x_inicial = imgsize[0] // (fraccion - 2)
  y_inicial = imgsize[1] // (fraccion - 2)
  alto = imgsize[1]
  ancho = imgsize[0]
  multip = fraccion / (fraccion - 2)
  img_size = (math.floor(ancho * multip) , math.floor(alto * multip))


  print(f"Ruta principal: {ruta_principal}")
  for carpeta_actual, _, archivos in os.walk(ruta_principal):
    print(f"Carpeta actual: {carpeta_actual}")
    for archivo in archivos:
      print(f"Archivo: {archivo}")
      ruta_completa = os.path.join(carpeta_actual, archivo)
      try:

            img = cv2.imread(ruta_completa, cv2.IMREAD_GRAYSCALE)

            img = cv2.normalize(img, None, 0, 255, cv2.NORM_MINMAX)

            if img is None:
                print(f"⚠️ No se pudo leer: {ruta_completa}")
                continue

            # Detectar rostros
            faces = face_cascade.detectMultiScale(img, scaleFactor=1.1, minNeighbors=10, minSize=(110, 110))

            for i, (x, y, w, h) in enumerate(faces):
                face = img[y:y+h, x:x+w]  # Recortar rostro
                face_resized = cv2.resize(face, img_size)  # Redimensionar

                face_cutted = face_resized[y_inicial:y_inicial+alto, x_inicial:x_inicial+ancho]

                # Crear carpeta de salida manteniendo la estructura original
                relative_path = os.path.relpath(carpeta_actual, ruta_entrada)
                output_folder = os.path.join(ruta_salida, relative_path)
                os.makedirs(output_folder, exist_ok=True)

                # Guardar rostro procesado
                output_path = os.path.join(output_folder, f"{os.path.splitext(archivo)[0]}_face{i}.jpg")
                cv2.imwrite(output_path, face_cutted)
                print(f"✅ Guardado: {output_path}")


      except Exception as e:
          print(f"❌ Error procesando {ruta_completa}: {e}")


      except Exception as e:
        print(f"Error al procesar el archivo {ruta_completa}: {e}")

# %%
# Preprocesamos imagenes (escala de grises, recortes y escalado)
print("Procesando archivos")
procesar_archivos_en_carpetas(ruta_entrada, ruta_salida, img_size)
print("Proceso inicial terminado ...")
# Out:
# Procesando archivos
# Ruta principal: /content/drive/MyDrive/Eigenfaces
# Carpeta actual: /content/drive/MyDrive/Eigenfaces
# Carpeta actual: /content/drive/MyDrive/Eigenfaces/Noelia M
# Archivo: 1742907849847.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/1742907849847_face0.jpg
# Archivo: 1742907849811.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/1742907849811_face0.jpg
# Archivo: 20250321_140807.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/20250321_140807_face0.jpg
# Archivo: 20250321_140804.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/20250321_140804_face0.jpg
# Archivo: 20250321_140808.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/20250321_140808_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/20250321_140808_face1.jpg
# Archivo: 1742907849823.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/1742907849823_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/1742907849823_face1.jpg
# Archivo: IMG_1073.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_1073_face0.jpg
# Archivo: IMG_1071.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_1071_face0.jpg
# Archivo: IMG_1602.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_1602_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_1602_face1.jpg
# Archivo: IMG_1268.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_1268_face0.jpg
# Archivo: IMG_1072.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_1072_face0.jpg
# Archivo: IMG_1267.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_1267_face0.jpg
# Archivo: IMG_1269.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_1269_face0.jpg
# Archivo: IMG_1607.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_1607_face0.jpg
# Archivo: IMG_20250321_140535510_HDR.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_20250321_140535510_HDR_face0.jpg
# Archivo: IMG_1606.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_1606_face0.jpg
# Archivo: IMG_20250321_140533679_HDR.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_20250321_140533679_HDR_face0.jpg
# Archivo: IMG_1611.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_1611_face0.jpg
# Archivo: IMG_1608.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_1608_face0.jpg
# Archivo: IMG_1609.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_1609_face0.jpg
# Archivo: IMG_20250321_140537614_HDR.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_20250321_140537614_HDR_face0.jpg
# Archivo: IMG_8972.jpeg
# Archivo: IMG_6813.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_6813_face0.jpg
# Archivo: IMG_4162.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_4162_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_4162_face1.jpg
# Archivo: IMG_6812.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_6812_face0.jpg
# Archivo: IMG_8971.jpeg
# Archivo: IMG_4163.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_4163_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_4163_face1.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_4163_face2.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_4163_face3.jpg
# Archivo: IMG_4161.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_4161_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_4161_face1.jpg
# Archivo: IMG_8974.jpeg
# Archivo: IMG_8973.jpeg
# Archivo: IMG_6811.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_6811_face0.jpg
# Archivo: IMG_8975.jpeg
# Archivo: IMG_8977.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_8977_face0.jpg
# Archivo: IMG_8983.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_8983_face0.jpg
# Archivo: IMG_8981.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_8981_face0.jpg
# Archivo: IMG_8979.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_8979_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_8979_face1.jpg
# Archivo: IMG_8982.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_8982_face0.jpg
# Archivo: IMG_8980.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_8980_face0.jpg
# Archivo: IMG_8976.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_8976_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_8976_face1.jpg
# Archivo: IMG_8978.jpeg
# Archivo: IMG_8985.jpeg
# Archivo: IMG_8984.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_8984_face0.jpg
# Archivo: IMG_8986.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_8986_face0.jpg
# Archivo: IMG_8992.jpeg
# Archivo: IMG_8987.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_8987_face0.jpg
# Archivo: IMG_8991.jpeg
# Archivo: IMG_8990.jpeg
# Archivo: IMG_8988.jpeg
# Archivo: IMG_8998.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_8998_face0.jpg
# Archivo: IMG_9001.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_9001_face0.jpg
# Archivo: IMG_8999.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_8999_face0.jpg
# Archivo: IMG_8989.jpeg
# Archivo: IMG_8993.jpeg
# Archivo: IMG_9003.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_9003_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_9003_face1.jpg
# Archivo: IMG_9002.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia M/IMG_9002_face0.jpg
# Carpeta actual: /content/drive/MyDrive/Eigenfaces/Jorgelina
# Archivo: 20250501_203113.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/20250501_203113_face0.jpg
# Archivo: 1742907849946.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/1742907849946_face0.jpg
# Archivo: 20250501_203122.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/20250501_203122_face0.jpg
# Archivo: 20250501_203039.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/20250501_203039_face0.jpg
# Archivo: 20250501_203118.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/20250501_203118_face0.jpg
# Archivo: 20250501_203115.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/20250501_203115_face0.jpg
# Archivo: 1742907849978.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/1742907849978_face0.jpg
# Archivo: 1742907849966.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/1742907849966_face0.jpg
# Archivo: 20250501_203127.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/20250501_203127_face0.jpg
# Archivo: IMG_1064.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_1064_face0.jpg
# Archivo: 20250501_203125.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/20250501_203125_face0.jpg
# Archivo: IMG_1063.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_1063_face0.jpg
# Archivo: IMG_1062.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_1062_face0.jpg
# Archivo: IMG_1550.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_1550_face0.jpg
# Archivo: IMG_1549.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_1549_face0.jpg
# Archivo: IMG_1552.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_1552_face0.jpg
# Archivo: IMG_1255.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_1255_face0.jpg
# Archivo: IMG_1257.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_1257_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_1257_face1.jpg
# Archivo: IMG_1555.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_1555_face0.jpg
# Archivo: IMG_1553.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_1553_face0.jpg
# Archivo: IMG_1551.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_1551_face0.jpg
# Archivo: IMG_1554.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_1554_face0.jpg
# Archivo: IMG_1256.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_1256_face0.jpg
# Archivo: IMG_20250321_140524420_HDR.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_20250321_140524420_HDR_face0.jpg
# Archivo: IMG_1557.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_1557_face0.jpg
# Archivo: IMG_1561.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_1561_face0.jpg
# Archivo: IMG_20250321_140522457.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_20250321_140522457_face0.jpg
# Archivo: IMG_1560.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_1560_face0.jpg
# Archivo: IMG_1559.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_1559_face0.jpg
# Archivo: IMG_1556.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_1556_face0.jpg
# Archivo: IMG_1558.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_1558_face0.jpg
# Archivo: IMG_7044.jpeg
# Archivo: IMG_4171.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_4171_face0.jpg
# Archivo: IMG_4170.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_4170_face0.jpg
# Archivo: IMG_4172.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_4172_face0.jpg
# Archivo: IMG_6805.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_6805_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_6805_face1.jpg
# Archivo: IMG_20250321_140526671.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_20250321_140526671_face0.jpg
# Archivo: IMG_6807.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_6807_face0.jpg
# Archivo: IMG_6806.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_6806_face0.jpg
# Archivo: IMG_7046.jpeg
# Archivo: IMG_7051.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_7051_face0.jpg
# Archivo: IMG_7048.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_7048_face0.jpg
# Archivo: IMG_7054.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_7054_face0.jpg
# Archivo: IMG_7052.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_7052_face0.jpg
# Archivo: IMG_7050.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_7050_face0.jpg
# Archivo: IMG_7049.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_7049_face0.jpg
# Archivo: IMG_7055.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_7055_face0.jpg
# Archivo: IMG_7045.jpeg
# Archivo: IMG_7053.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_7053_face0.jpg
# Archivo: IMG_7047.jpeg
# Archivo: IMG_7061.jpeg
# Archivo: IMG_7060.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_7060_face0.jpg
# Archivo: IMG_7647.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_7647_face0.jpg
# Archivo: IMG_7063.jpeg
# Archivo: IMG_7057.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_7057_face0.jpg
# Archivo: IMG_7062.jpeg
# Archivo: IMG_7064.jpeg
# Archivo: IMG_7058.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_7058_face0.jpg
# Archivo: IMG_7056.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_7056_face0.jpg
# Archivo: IMG_7059.jpeg
# Archivo: IMG_9041.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_9041_face0.jpg
# Archivo: IMG_8661.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_8661_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_8661_face1.jpg
# Archivo: IMG_8660.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_8660_face0.jpg
# Archivo: IMG_8662.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_8662_face0.jpg
# Archivo: IMG_9038.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_9038_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_9038_face1.jpg
# Archivo: IMG_9040.jpeg
# Archivo: IMG_7649 2.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_7649 2_face0.jpg
# Archivo: IMG_9039.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_9039_face0.jpg
# Archivo: IMG_7649.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Jorgelina/IMG_7649_face0.jpg
# Carpeta actual: /content/drive/MyDrive/Eigenfaces/José
# Archivo: 1742907850116.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/1742907850116_face0.jpg
# Archivo: IMG_1091.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_1091_face0.jpg
# Archivo: 1742907850125.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/1742907850125_face0.jpg
# Archivo: IMG_1246.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_1246_face0.jpg
# Archivo: 1742907850132.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/1742907850132_face0.jpg
# Archivo: 20250321_140327.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/20250321_140327_face0.jpg
# Archivo: IMG_1090.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_1090_face0.jpg
# Archivo: 20250321_140328.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/20250321_140328_face0.jpg
# Archivo: 20250321_140325.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/20250321_140325_face0.jpg
# Archivo: IMG_1092.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_1092_face0.jpg
# Archivo: IMG_20250321_140705033_HDR.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_20250321_140705033_HDR_face0.jpg
# Archivo: IMG_1247.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_1247_face0.jpg
# Archivo: IMG_1248.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_1248_face0.jpg
# Archivo: IMG_20250404_150027026.jpg
# Archivo: IMG_20250321_140709919_HDR.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_20250321_140709919_HDR_face0.jpg
# Archivo: IMG_20250321_140707409_HDR.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_20250321_140707409_HDR_face0.jpg
# Archivo: IMG_20250404_150029365.jpg
# Archivo: IMG_20250404_150035539.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_20250404_150035539_face0.jpg
# Archivo: IMG_20250404_150056289.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_20250404_150056289_face0.jpg
# Archivo: IMG_20250404_150038084.jpg
# Archivo: IMG_20250404_150110866.jpg
# Archivo: IMG_20250404_150047390.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_20250404_150047390_face0.jpg
# Archivo: IMG_20250404_150053977.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_20250404_150053977_face0.jpg
# Archivo: IMG_20250404_150102487.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_20250404_150102487_face0.jpg
# Archivo: IMG_20250404_150045179.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_20250404_150045179_face0.jpg
# Archivo: IMG_20250404_150105079.jpg
# Archivo: IMG_20250404_150121029.jpg
# Archivo: IMG_20250404_150743212.jpg
# Archivo: IMG_20250404_150745598.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_20250404_150745598_face0.jpg
# Archivo: IMG_20250404_150737498.jpg
# Archivo: IMG_20250404_150747819.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_20250404_150747819_face0.jpg
# Archivo: IMG_20250404_150749578.jpg
# Archivo: IMG_20250404_150740455.jpg
# Archivo: IMG_20250404_150112738.jpg
# Archivo: IMG_20250404_150118625.jpg
# Archivo: IMG_7619.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_7619_face0.jpg
# Archivo: IMG_6793.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_6793_face0.jpg
# Archivo: IMG_4177.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_4177_face0.jpg
# Archivo: IMG_7626.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_7626_face0.jpg
# Archivo: IMG_6792.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_6792_face0.jpg
# Archivo: IMG_6794.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_6794_face0.jpg
# Archivo: IMG_20250404_150751549.jpg
# Archivo: IMG_4178.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_4178_face0.jpg
# Archivo: IMG_4179.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_4179_face0.jpg
# Archivo: IMG_7618.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_7618_face0.jpg
# Archivo: IMG_8665.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_8665_face0.jpg
# Archivo: IMG_8663.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_8663_face0.jpg
# Archivo: IMG_8664.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/José/IMG_8664_face0.jpg
# Carpeta actual: /content/drive/MyDrive/Eigenfaces/Mauricio
# Archivo: 20250321_140642.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/20250321_140642_face0.jpg
# Archivo: IMG_0209[1].jpg
# Archivo: IMG_0207[1].jpg
# Archivo: 20250321_140644.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/20250321_140644_face0.jpg
# Archivo: 20250321_140645.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/20250321_140645_face0.jpg
# Archivo: IMG_0208[1].jpg
# Archivo: IMG_0210[1].jpg
# Archivo: IMG_0219[1].jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_0219[1]_face0.jpg
# Archivo: IMG_0216[1].jpg
# Archivo: IMG_0211[1].jpg
# Archivo: IMG_0213[1].jpg
# Archivo: IMG_0220[1].jpg
# Archivo: IMG_0212[1].jpg
# Archivo: IMG_0217[1].jpg
# Archivo: IMG_0218[1].jpg
# Archivo: IMG_0214[1].jpg
# Archivo: IMG_0221[1].jpg
# Archivo: IMG_0215[1].jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_0215[1]_face0.jpg
# Archivo: IMG_0224[1].jpg
# Archivo: IMG_0226[1].jpg
# Archivo: IMG_0222[1].jpg
# Archivo: IMG_0229[1].jpg
# Archivo: IMG_0223[1].jpg
# Archivo: IMG_1074.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_1074_face0.jpg
# Archivo: IMG_0225[1].jpg
# Archivo: IMG_0228[1].jpg
# Archivo: IMG_0227[1].jpg
# Archivo: IMG_1076.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_1076_face0.jpg
# Archivo: IMG_20250321_140502288_HDR.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_20250321_140502288_HDR_face0.jpg
# Archivo: IMG_1263.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_1263_face0.jpg
# Archivo: IMG_1261.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_1261_face0.jpg
# Archivo: IMG_1262.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_1262_face0.jpg
# Archivo: IMG_20250321_140456357_HDR.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_20250321_140456357_HDR_face0.jpg
# Archivo: IMG_1075.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_1075_face0.jpg
# Archivo: IMG_4160.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_4160_face0.jpg
# Archivo: IMG_6810.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_6810_face0.jpg
# Archivo: IMG_4159.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_4159_face0.jpg
# Archivo: IMG_6809.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_6809_face0.jpg
# Archivo: IMG_20250321_140504119_HDR.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_20250321_140504119_HDR_face0.jpg
# Archivo: IMG_7635 2.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_7635 2_face0.jpg
# Archivo: IMG_8654.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_8654_face0.jpg
# Archivo: IMG_7634 2.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_7634 2_face0.jpg
# Archivo: IMG_8653.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_8653_face0.jpg
# Archivo: IMG_6808.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_6808_face0.jpg
# Archivo: IMG_7635.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_7635_face0.jpg
# Archivo: IMG_4158.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_4158_face0.jpg
# Archivo: IMG_8655.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Mauricio/IMG_8655_face0.jpg
# Carpeta actual: /content/drive/MyDrive/Eigenfaces/Gabriel
# Archivo: 1742907849736.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/1742907849736_face0.jpg
# Archivo: 0B0181F5-4B8E-4457-B806-76ED18D03ECC_1_105_c.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/0B0181F5-4B8E-4457-B806-76ED18D03ECC_1_105_c_face0.jpg
# Archivo: 20250321_170526.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/20250321_170526_face0.jpg
# Archivo: BFDD433C-0C61-490B-B8C7-C4A06579E4D5_1_105_c.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/BFDD433C-0C61-490B-B8C7-C4A06579E4D5_1_105_c_face0.jpg
# Archivo: 1742907849742.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/1742907849742_face0.jpg
# Archivo: IMG_1101.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_1101_face0.jpg
# Archivo: 20250321_170525.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/20250321_170525_face0.jpg
# Archivo: 1742907849749.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/1742907849749_face0.jpg
# Archivo: FBC2385B-C170-4DFF-8326-427CA84D31AE_1_105_c.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/FBC2385B-C170-4DFF-8326-427CA84D31AE_1_105_c_face0.jpg
# Archivo: 20250321_170523.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/20250321_170523_face0.jpg
# Archivo: IMG_1636.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_1636_face0.jpg
# Archivo: IMG_1102.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_1102_face0.jpg
# Archivo: IMG_1635.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_1635_face0.jpg
# Archivo: IMG_1290.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_1290_face0.jpg
# Archivo: IMG_1103.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_1103_face0.jpg
# Archivo: IMG_1289.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_1289_face0.jpg
# Archivo: IMG_1637.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_1637_face0.jpg
# Archivo: IMG_1288.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_1288_face0.jpg
# Archivo: IMG_1638.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_1638_face0.jpg
# Archivo: IMG_1642.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_1642_face0.jpg
# Archivo: IMG_1641.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_1641_face0.jpg
# Archivo: IMG_1644.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_1644_face0.jpg
# Archivo: IMG_1639.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_1639_face0.jpg
# Archivo: IMG_1640.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_1640_face0.jpg
# Archivo: IMG_1645.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_1645_face0.jpg
# Archivo: IMG_1647.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_1647_face0.jpg
# Archivo: IMG_4197.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_4197_face0.jpg
# Archivo: IMG_20250321_170535204.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_20250321_170535204_face0.jpg
# Archivo: IMG_4195.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_4195_face0.jpg
# Archivo: IMG_20250321_170531711.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_20250321_170531711_face0.jpg
# Archivo: IMG_1646.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_1646_face0.jpg
# Archivo: IMG_4196.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_4196_face0.jpg
# Archivo: IMG_20250321_170533482.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_20250321_170533482_face0.jpg
# Archivo: IMG_6824.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_6824_face0.jpg
# Archivo: IMG_6825.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_6825_face0.jpg
# Archivo: IMG_7699.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_7699_face0.jpg
# Archivo: IMG_7700 2.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_7700 2_face0.jpg
# Archivo: IMG_8693.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_8693_face0.jpg
# Archivo: IMG_6823.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_6823_face0.jpg
# Archivo: IMG_8692.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_8692_face0.jpg
# Archivo: IMG_7699 2.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_7699 2_face0.jpg
# Archivo: IMG_8691.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gabriel/IMG_8691_face0.jpg
# Carpeta actual: /content/drive/MyDrive/Eigenfaces/Gustavo
# Archivo: 1743949289665.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/1743949289665_face0.jpg
# Archivo: 1743949289676.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/1743949289676_face0.jpg
# Archivo: 1743949289691.jpg
# Archivo: 1743949289699.jpg
# Archivo: 1743949289685.jpg
# Archivo: 1743949289706.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/1743949289706_face0.jpg
# Archivo: 1743949289670.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/1743949289670_face0.jpg
# Archivo: 1743949289714.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/1743949289714_face0.jpg
# Archivo: 1743949289777.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/1743949289777_face0.jpg
# Archivo: 1743949289725.jpg
# Archivo: 1743949289733.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/1743949289733_face0.jpg
# Archivo: 1743949289741.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/1743949289741_face0.jpg
# Archivo: 1743949289760.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/1743949289760_face0.jpg
# Archivo: 1743949289768.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/1743949289768_face0.jpg
# Archivo: 1743949289796.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/1743949289796_face0.jpg
# Archivo: 1743949289751.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/1743949289751_face0.jpg
# Archivo: 1743949289788.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/1743949289788_face0.jpg
# Archivo: 1743949289839.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/1743949289839_face0.jpg
# Archivo: 1743949289867.jpg
# Archivo: 20250404_150814.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/20250404_150814_face0.jpg
# Archivo: 1743949289805.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/1743949289805_face0.jpg
# Archivo: 1743949289820.jpg
# Archivo: 20250404_150811.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/20250404_150811_face0.jpg
# Archivo: 1743949289877.jpg
# Archivo: 1743949289887.jpg
# Archivo: 1743949289850.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/1743949289850_face0.jpg
# Archivo: IMG_1200.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_1200_face0.jpg
# Archivo: IMG_1529.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_1529_face0.jpg
# Archivo: IMG_1532.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_1532_face0.jpg
# Archivo: IMG_1201.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_1201_face0.jpg
# Archivo: IMG_1202.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_1202_face0.jpg
# Archivo: IMG_1530.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_1530_face0.jpg
# Archivo: 20250404_150817.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/20250404_150817_face0.jpg
# Archivo: IMG_1534.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_1534_face0.jpg
# Archivo: IMG_1531.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_1531_face0.jpg
# Archivo: IMG_1535.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_1535_face0.jpg
# Archivo: IMG_1536.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_1536_face0.jpg
# Archivo: IMG_20250404_150835.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_20250404_150835_face0.jpg
# Archivo: IMG_20250404_150842750.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_20250404_150842750_face0.jpg
# Archivo: IMG_6348.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_6348_face0.jpg
# Archivo: IMG_20250404_150837.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_20250404_150837_face0.jpg
# Archivo: IMG_4320.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_4320_face0.jpg
# Archivo: IMG_20250404_150845430.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_20250404_150845430_face0.jpg
# Archivo: IMG_4322.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_4322_face0.jpg
# Archivo: IMG_20250404_150847899.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_20250404_150847899_face0.jpg
# Archivo: IMG_20250404_150839.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_20250404_150839_face0.jpg
# Archivo: IMG_6349.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_6349_face0.jpg
# Archivo: IMG_6347.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_6347_face0.jpg
# Archivo: IMG_4321.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_4321_face0.jpg
# Archivo: IMG_7066.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_7066_face0.jpg
# Archivo: IMG_7787 2.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_7787 2_face0.jpg
# Archivo: IMG_7067.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_7067_face0.jpg
# Archivo: IMG_7786.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_7786_face0.jpg
# Archivo: IMG_8994.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_8994_face0.jpg
# Archivo: IMG_8997.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_8997_face0.jpg
# Archivo: IMG_8996.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_8996_face0.jpg
# Archivo: IMG_7065.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_7065_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_7065_face1.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_7065_face2.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_7065_face3.jpg
# Archivo: IMG_8995.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_8995_face0.jpg
# Archivo: IMG_7786 2.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Gustavo/IMG_7786 2_face0.jpg
# Carpeta actual: /content/drive/MyDrive/Eigenfaces/Natalia
# Archivo: 20250321_140633.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/20250321_140633_face0.jpg
# Archivo: 1742907849888.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/1742907849888_face0.jpg
# Archivo: 20250404_150056.jpg
# Archivo: 1742907849896.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/1742907849896_face0.jpg
# Archivo: 1742907849879.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/1742907849879_face0.jpg
# Archivo: 20250321_140636.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/20250321_140636_face0.jpg
# Archivo: 20250321_140638.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/20250321_140638_face0.jpg
# Archivo: 20250404_150107.jpg
# Archivo: 20250404_150109.jpg
# Archivo: 20250404_150115.jpg
# Archivo: 20250404_150118.jpg
# Archivo: 20250404_150059.jpg
# Archivo: 20250404_150133.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/20250404_150133_face0.jpg
# Archivo: 20250404_150105.jpg
# Archivo: 20250404_150101.jpg
# Archivo: 20250404_150120.jpg
# Archivo: 20250404_150151.jpg
# Archivo: 20250404_150135.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/20250404_150135_face0.jpg
# Archivo: 20250404_150158.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/20250404_150158_face0.jpg
# Archivo: 20250404_150149.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/20250404_150149_face0.jpg
# Archivo: 20250404_150202.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/20250404_150202_face0.jpg
# Archivo: 20250404_150208.jpg
# Archivo: 20250404_150200.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/20250404_150200_face0.jpg
# Archivo: 20250404_150146.jpg
# Archivo: 20250404_150206.jpg
# Archivo: 20250404_150142.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/20250404_150142_face0.jpg
# Archivo: IMG_1068.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_1068_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_1068_face1.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_1068_face2.jpg
# Archivo: 20250404_150210.jpg
# Archivo: IMG_1069.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_1069_face0.jpg
# Archivo: IMG_1070.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_1070_face0.jpg
# Archivo: IMG_1587.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_1587_face0.jpg
# Archivo: IMG_1592.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_1592_face0.jpg
# Archivo: IMG_1591.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_1591_face0.jpg
# Archivo: IMG_1586.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_1586_face0.jpg
# Archivo: IMG_1259.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_1259_face0.jpg
# Archivo: IMG_1260.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_1260_face0.jpg
# Archivo: IMG_1590.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_1590_face0.jpg
# Archivo: IMG_1258.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_1258_face0.jpg
# Archivo: IMG_1589.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_1589_face0.jpg
# Archivo: IMG_20250321_140449310_HDR.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_20250321_140449310_HDR_face0.jpg
# Archivo: IMG_1595.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_1595_face0.jpg
# Archivo: IMG_4165.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_4165_face0.jpg
# Archivo: IMG_4164.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_4164_face0.jpg
# Archivo: IMG_1593.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_1593_face0.jpg
# Archivo: IMG_1594.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_1594_face0.jpg
# Archivo: IMG_20250321_140447827_HDR.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_20250321_140447827_HDR_face0.jpg
# Archivo: IMG_20250321_140446409_HDR.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_20250321_140446409_HDR_face0.jpg
# Archivo: IMG_7816.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_7816_face0.jpg
# Archivo: IMG_7819.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_7819_face0.jpg
# Archivo: IMG_7815.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_7815_face0.jpg
# Archivo: IMG_7817.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_7817_face0.jpg
# Archivo: IMG_7820.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_7820_face0.jpg
# Archivo: IMG_7639.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_7639_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_7639_face1.jpg
# Archivo: IMG_4166.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_4166_face0.jpg
# Archivo: IMG_8675.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_8675_face0.jpg
# Archivo: IMG_7818.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_7818_face0.jpg
# Archivo: IMG_7640 2.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_7640 2_face0.jpg
# Archivo: IMG_7821.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_7821_face0.jpg
# Archivo: IMG_7639 2.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_7639 2_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_7639 2_face1.jpg
# Archivo: IMG_7814.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_7814_face0.jpg
# Archivo: IMG_9031.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_9031_face0.jpg
# Archivo: IMG_9033.jpeg
# Archivo: IMG_9030.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_9030_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_9030_face1.jpg
# Archivo: IMG_9029.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_9029_face0.jpg
# Archivo: IMG_8677.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_8677_face0.jpg
# Archivo: IMG_9032.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_9032_face0.jpg
# Archivo: IMG_9034.jpeg
# Archivo: IMG_9035.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_9035_face0.jpg
# Archivo: IMG_9036.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_9036_face0.jpg
# Archivo: IMG_8676.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_8676_face0.jpg
# Archivo: IMG_9037.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_9037_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Natalia/IMG_9037_face1.jpg
# Carpeta actual: /content/drive/MyDrive/Eigenfaces/Noelia R
# Archivo: 20250321_170641.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/20250321_170641_face0.jpg
# Archivo: 20250321_170639.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/20250321_170639_face0.jpg
# Archivo: 1742907849918.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/1742907849918_face0.jpg
# Archivo: 1742907849908.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/1742907849908_face0.jpg
# Archivo: 20250321_170637.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/20250321_170637_face0.jpg
# Archivo: IMG_1104.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_1104_face0.jpg
# Archivo: 1742907849929.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/1742907849929_face0.jpg
# Archivo: IMG_1539.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_1539_face0.jpg
# Archivo: IMG_1106.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_1106_face0.jpg
# Archivo: IMG_1105.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_1105_face0.jpg
# Archivo: IMG_1266.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_1266_face0.jpg
# Archivo: IMG_1538.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_1538_face0.jpg
# Archivo: IMG_1264.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_1264_face0.jpg
# Archivo: IMG_1265.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_1265_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_1265_face1.jpg
# Archivo: IMG_1541.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_1541_face0.jpg
# Archivo: IMG_1540.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_1540_face0.jpg
# Archivo: IMG_20250321_140824265.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_20250321_140824265_face0.jpg
# Archivo: IMG_1544.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_1544_face0.jpg
# Archivo: IMG_1546.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_1546_face0.jpg
# Archivo: IMG_1548.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_1548_face0.jpg
# Archivo: IMG_1542.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_1542_face0.jpg
# Archivo: IMG_1547.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_1547_face0.jpg
# Archivo: IMG_1543.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_1543_face0.jpg
# Archivo: IMG_1545.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_1545_face0.jpg
# Archivo: IMG_4185.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_4185_face0.jpg
# Archivo: IMG_20250321_170634292.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_20250321_170634292_face0.jpg
# Archivo: IMG_20250321_170631563.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_20250321_170631563_face0.jpg
# Archivo: IMG_4186.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_4186_face0.jpg
# Archivo: IMG_6802.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_6802_face0.jpg
# Archivo: IMG_20250321_170629085.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_20250321_170629085_face0.jpg
# Archivo: IMG_6804.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_6804_face0.jpg
# Archivo: IMG_6803.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_6803_face0.jpg
# Archivo: IMG_4184.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_4184_face0.jpg
# Archivo: IMG_7655 2.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_7655 2_face0.jpg
# Archivo: IMG_7765.JPG
# Archivo: IMG_7655.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_7655_face0.jpg
# Archivo: IMG_7657.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_7657_face0.jpg
# Archivo: IMG_7762.JPG
# Archivo: IMG_7766.JPG
# Archivo: IMG_7761.JPG
# Archivo: IMG_7764.JPG
# Archivo: IMG_7763.JPG
# Archivo: IMG_7772.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_7772_face0.jpg
# Archivo: IMG_7770.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_7770_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_7770_face1.jpg
# Archivo: IMG_7769.JPG
# Archivo: IMG_7774.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_7774_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_7774_face1.jpg
# Archivo: IMG_7768.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_7768_face0.jpg
# Archivo: IMG_7775.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_7775_face0.jpg
# Archivo: IMG_7767.JPG
# Archivo: IMG_7771.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_7771_face0.jpg
# Archivo: IMG_7779.JPG
# Archivo: IMG_7776.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_7776_face0.jpg
# Archivo: IMG_7782.JPG
# Archivo: IMG_7781.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Noelia R/IMG_7781_face0.jpg
# Archivo: IMG_7777.JPG
# Archivo: IMG_7780.JPG
# Carpeta actual: /content/drive/MyDrive/Eigenfaces/Federico
# Archivo: 1742907849997.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/1742907849997_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/1742907849997_face1.jpg
# Archivo: 1742907850046.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/1742907850046_face0.jpg
# Archivo: 20250321_140309.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/20250321_140309_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/20250321_140309_face1.jpg
# Archivo: IMG_1078.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1078_face0.jpg
# Archivo: 1742907850028.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/1742907850028_face0.jpg
# Archivo: 20250321_140311.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/20250321_140311_face0.jpg
# Archivo: 20250321_140307.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/20250321_140307_face0.jpg
# Archivo: IMG_1077.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1077_face0.jpg
# Archivo: IMG_1183.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1183_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1183_face1.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1183_face2.jpg
# Archivo: IMG_1185.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1185_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1185_face1.jpg
# Archivo: IMG_1186.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1186_face0.jpg
# Archivo: IMG_1187.JPG
# Archivo: IMG_1184.JPG
# Archivo: IMG_1079.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1079_face0.jpg
# Archivo: IMG_1180.JPG
# Archivo: IMG_1181.JPG
# Archivo: IMG_1182.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1182_face0.jpg
# Archivo: IMG_1179.JPG
# Archivo: IMG_1197.JPG
# Archivo: IMG_1188.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1188_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1188_face1.jpg
# Archivo: IMG_1189.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1189_face0.jpg
# Archivo: IMG_1190.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1190_face0.jpg
# Archivo: IMG_1196.JPG
# Archivo: IMG_1194.JPG
# Archivo: IMG_1193.JPG
# Archivo: IMG_1192.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1192_face0.jpg
# Archivo: IMG_1195.JPG
# Archivo: IMG_1191.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1191_face0.jpg
# Archivo: IMG_1562.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1562_face0.jpg
# Archivo: IMG_1254.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1254_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1254_face1.jpg
# Archivo: IMG_1198.JPG
# Archivo: IMG_1252.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1252_face0.jpg
# Archivo: IMG_1565.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1565_face0.jpg
# Archivo: IMG_1253.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1253_face0.jpg
# Archivo: IMG_1564.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1564_face0.jpg
# Archivo: IMG_1563.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1563_face0.jpg
# Archivo: IMG_1199.JPG
# Archivo: IMG_1573.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1573_face0.jpg
# Archivo: IMG_1570.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1570_face0.jpg
# Archivo: IMG_1572.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1572_face0.jpg
# Archivo: IMG_1567.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1567_face0.jpg
# Archivo: IMG_4181.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_4181_face0.jpg
# Archivo: IMG_1566.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Federico/IMG_1566_face0.jpg
# ...
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_20250404_150323_face0.jpg
# Archivo: IMG_20250321_140517288.jpg
# Archivo: IMG_20250404_150349.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_20250404_150349_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_20250404_150349_face1.jpg
# Archivo: IMG_20250404_150348.jpg
# Archivo: IMG_20250404_150334.jpg
# Archivo: IMG_20250404_150340.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_20250404_150340_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_20250404_150340_face1.jpg
# Archivo: IMG_20250404_150338.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_20250404_150338_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_20250404_150338_face1.jpg
# Archivo: IMG_20250404_150342.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_20250404_150342_face0.jpg
# Archivo: IMG_20250404_150351.jpg
# Archivo: IMG_20250404_150332.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_20250404_150332_face0.jpg
# Archivo: IMG_20250404_150401.jpg
# Archivo: IMG_4169.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_4169_face0.jpg
# Archivo: IMG_4167.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_4167_face0.jpg
# Archivo: IMG_20250404_150405.jpg
# Archivo: IMG_20250404_150409.jpg
# Archivo: IMG_20250404_150407.jpg
# Archivo: IMG_20250404_150359.jpg
# Archivo: IMG_20250404_150400.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_20250404_150400_face0.jpg
# Archivo: IMG_4168.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_4168_face0.jpg
# Archivo: IMG_7667.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_7667_face0.jpg
# Archivo: IMG_8672.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_8672_face0.jpg
# Archivo: IMG_7668 2.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_7668 2_face0.jpg
# Archivo: IMG_6816.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_6816_face0.jpg
# Archivo: IMG_8673.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_8673_face0.jpg
# Archivo: IMG_7667 2.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_7667 2_face0.jpg
# Archivo: IMG_8674.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_8674_face0.jpg
# Archivo: IMG_6815.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_6815_face0.jpg
# Archivo: IMG_6814.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Daniel/IMG_6814_face0.jpg
# Carpeta actual: /content/drive/MyDrive/Eigenfaces/Agustín
# Archivo: 1742907850091.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/1742907850091_face0.jpg
# Archivo: 1742907850098.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/1742907850098_face0.jpg
# Archivo: 20250321_140317.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/20250321_140317_face0.jpg
# Archivo: 20250321_140319.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/20250321_140319_face0.jpg
# Archivo: IMG_1084.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/IMG_1084_face0.jpg
# Archivo: 1742907850107.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/1742907850107_face0.jpg
# Archivo: 20250321_140321.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/20250321_140321_face0.jpg
# Archivo: IMG_1086.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/IMG_1086_face0.jpg
# Archivo: IMG_4176.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/IMG_4176_face0.jpg
# Archivo: IMG_20250321_140716918_HDR.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/IMG_20250321_140716918_HDR_face0.jpg
# Archivo: IMG_4175.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/IMG_4175_face0.jpg
# Archivo: IMG_1085.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/IMG_1085_face0.jpg
# Archivo: IMG_4174.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/IMG_4174_face0.jpg
# Archivo: IMG_20250321_140715339.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/IMG_20250321_140715339_face0.jpg
# Archivo: IMG_20250321_140718770_HDR.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/IMG_20250321_140718770_HDR_face0.jpg
# Archivo: IMG_7613 2.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/IMG_7613 2_face0.jpg
# Archivo: IMG_8671.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/IMG_8671_face0.jpg
# Archivo: IMG_6790.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/IMG_6790_face0.jpg
# Archivo: IMG_6791.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/IMG_6791_face0.jpg
# Archivo: IMG_8670.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/IMG_8670_face0.jpg
# Archivo: IMG_8669.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/IMG_8669_face0.jpg
# Archivo: IMG_7609.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/IMG_7609_face0.jpg
# Archivo: IMG_7609 2.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/IMG_7609 2_face0.jpg
# Archivo: IMG_6789.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Agustín/IMG_6789_face0.jpg
# Carpeta actual: /content/drive/MyDrive/Eigenfaces/Alejandro
# Archivo: 1742907849755.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/1742907849755_face0.jpg
# Archivo: 20250321_170445.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/20250321_170445_face0.jpg
# Archivo: 20250321_170448.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/20250321_170448_face0.jpg
# Archivo: 20250321_170439.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/20250321_170439_face0.jpg
# Archivo: 1742907849769.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/1742907849769_face0.jpg
# Archivo: 1742907849763.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/1742907849763_face0.jpg
# Archivo: IMG_1098.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_1098_face0.jpg
# Archivo: IMG_1627.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_1627_face0.jpg
# Archivo: IMG_1286.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_1286_face0.jpg
# Archivo: IMG_1100.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_1100_face0.jpg
# Archivo: IMG_1099.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_1099_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_1099_face1.jpg
# Archivo: IMG_1285.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_1285_face0.jpg
# Archivo: IMG_1625.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_1625_face0.jpg
# Archivo: IMG_1287.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_1287_face0.jpg
# Archivo: IMG_1626.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_1626_face0.jpg
# Archivo: IMG_20250321_170502353.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_20250321_170502353_face0.jpg
# Archivo: IMG_1631.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_1631_face0.jpg
# Archivo: IMG_20250321_170500203.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_20250321_170500203_face0.jpg
# Archivo: IMG_4192.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_4192_face0.jpg
# Archivo: IMG_20250321_170457147.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_20250321_170457147_face0.jpg
# Archivo: IMG_1628.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_1628_face0.jpg
# Archivo: IMG_1632.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_1632_face0.jpg
# Archivo: IMG_1630.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_1630_face0.jpg
# Archivo: IMG_1629.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_1629_face0.jpg
# Archivo: IMG_4295.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_4295_face0.jpg
# Archivo: IMG_4194.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_4194_face0.jpg
# Archivo: IMG_4300.JPG
# Archivo: IMG_4301.JPG
# Archivo: IMG_4298.JPG
# Archivo: IMG_4297.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_4297_face0.jpg
# Archivo: IMG_4296.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_4296_face0.jpg
# Archivo: IMG_4303.JPG
# Archivo: IMG_4193.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_4193_face0.jpg
# Archivo: IMG_4299.JPG
# Archivo: IMG_4302.JPG
# Archivo: IMG_4310.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_4310_face0.jpg
# Archivo: IMG_4305.JPG
# Archivo: IMG_4313.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_4313_face0.jpg
# Archivo: IMG_4308.JPG
# Archivo: IMG_4309.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_4309_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_4309_face1.jpg
# Archivo: IMG_4306.JPG
# Archivo: IMG_4311.JPG
# Archivo: IMG_4304.JPG
# Archivo: IMG_4307.JPG
# Archivo: IMG_4312.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_4312_face0.jpg
# Archivo: IMG_4317.JPG
# Archivo: IMG_4319.JPG
# Archivo: IMG_4316.JPG
# Archivo: IMG_7688.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_7688_face0.jpg
# Archivo: IMG_4318.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_4318_face0.jpg
# Archivo: IMG_6822.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_6822_face0.jpg
# Archivo: IMG_4314.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_4314_face0.jpg
# Archivo: IMG_6820.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_6820_face0.jpg
# Archivo: IMG_6821.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_6821_face0.jpg
# Archivo: IMG_4315.JPG
# Archivo: IMG_7688 2.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_7688 2_face0.jpg
# Archivo: IMG_8689.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_8689_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_8689_face1.jpg
# Archivo: IMG_7689 2.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_7689 2_face0.jpg
# Archivo: IMG_8688.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_8688_face0.jpg
# Archivo: IMG_8690.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Alejandro/IMG_8690_face0.jpg
# Carpeta actual: /content/drive/MyDrive/Eigenfaces/Cristian
# Archivo: ._Foto5.png
# ⚠️ No se pudo leer: /content/drive/MyDrive/Eigenfaces/Cristian/._Foto5.png
# Archivo: 1742907849798.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/1742907849798_face0.jpg
# Archivo: ._Foto1.png
# ⚠️ No se pudo leer: /content/drive/MyDrive/Eigenfaces/Cristian/._Foto1.png
# Archivo: 1742907849776.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/1742907849776_face0.jpg
# Archivo: ._Foto2.png
# ⚠️ No se pudo leer: /content/drive/MyDrive/Eigenfaces/Cristian/._Foto2.png
# Archivo: ._Foto6.png
# ⚠️ No se pudo leer: /content/drive/MyDrive/Eigenfaces/Cristian/._Foto6.png
# Archivo: ._Foto4.png
# ⚠️ No se pudo leer: /content/drive/MyDrive/Eigenfaces/Cristian/._Foto4.png
# Archivo: ._Foto7.png
# ⚠️ No se pudo leer: /content/drive/MyDrive/Eigenfaces/Cristian/._Foto7.png
# Archivo: ._Foto3.png
# ⚠️ No se pudo leer: /content/drive/MyDrive/Eigenfaces/Cristian/._Foto3.png
# Archivo: 1742907849783.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/1742907849783_face0.jpg
# Archivo: Foto2.png
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/Foto2_face0.jpg
# Archivo: Captura de pantalla 2025-05-01 a la(s) 8.31.45ÔÇ»p.┬ám..png
# Archivo: 20250321_170423.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/20250321_170423_face0.jpg
# Archivo: Captura de pantalla 2025-05-01 a la(s) 8.30.50ÔÇ»p.┬ám..png
# Archivo: Captura de pantalla 2025-05-01 a la(s) 8.33.23ÔÇ»p.┬ám..png
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/Captura de pantalla 2025-05-01 a la(s) 8.33.23ÔÇ»p.┬ám._face0.jpg
# Archivo: Captura de pantalla 2025-05-01 a la(s) 8.32.17ÔÇ»p.┬ám..png
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/Captura de pantalla 2025-05-01 a la(s) 8.32.17ÔÇ»p.┬ám._face0.jpg
# Archivo: Foto4.png
# Archivo: 20250321_170432.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/20250321_170432_face0.jpg
# Archivo: Foto3.png
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/Foto3_face0.jpg
# Archivo: 20250321_170427.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/20250321_170427_face0.jpg
# Archivo: Captura de pantalla 2025-05-01 a la(s) 8.32.23ÔÇ»p.┬ám..png
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/Captura de pantalla 2025-05-01 a la(s) 8.32.23ÔÇ»p.┬ám._face0.jpg
# Archivo: Foto1.png
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/Foto1_face0.jpg
# Archivo: Foto5.png
# Archivo: IMG_1095.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_1095_face0.jpg
# Archivo: IMG_1282.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_1282_face0.jpg
# Archivo: Foto6.png
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/Foto6_face0.jpg
# Archivo: IMG_1096.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_1096_face0.jpg
# Archivo: Foto7.png
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/Foto7_face0.jpg
# Archivo: IMG_1097.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_1097_face0.jpg
# Archivo: IMG_20250321_170437206_HDR.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_20250321_170437206_HDR_face0.jpg
# Archivo: IMG_4190.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_4190_face0.jpg
# Archivo: IMG_20250321_170439519.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_20250321_170439519_face0.jpg
# Archivo: IMG_6817.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_6817_face0.jpg
# Archivo: IMG_1284.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_1284_face0.jpg
# Archivo: IMG_1283.jpeg
# Archivo: IMG_4189.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_4189_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_4189_face1.jpg
# Archivo: IMG_6818.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_6818_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_6818_face1.jpg
# Archivo: IMG_4191.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_4191_face0.jpg
# Archivo: IMG_20250321_170444007_HDR.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_20250321_170444007_HDR_face0.jpg
# Archivo: IMG_8686.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_8686_face0.jpg
# Archivo: IMG_7686 2.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_7686 2_face0.jpg
# Archivo: IMG_8685.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_8685_face0.jpg
# Archivo: IMG_6819.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_6819_face0.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_6819_face1.jpg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_6819_face2.jpg
# Archivo: IMG_7681.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_7681_face0.jpg
# Archivo: IMG_8687.jpeg
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_8687_face0.jpg
# Archivo: IMG_7681 2.JPG
# ✅ Guardado: /content/drive/MyDrive/Eigenfaces2-60x60/Cristian/IMG_7681 2_face0.jpg
# Proceso inicial terminado ...

# %% [markdown]
# ## el preprocesado queda en la carpeta Eigenfaces2-60x60
#
# ### copie una version de esa carpeta a "origen" para usar a continuacion

# %%
# origen de datos preprocesados
ruta_origen = "/content/drive/MyDrive/Origen"

# %%
# Dividimos conjunto de datos

def dividir_datos(ruta_origen, proporcion_entrenamiento=0.75):
    """
    Divide las imágenes en conjuntos de entrenamiento y prueba,
    y guarda las etiquetas usando un diccionario de listas.

    Args:
        ruta_origen (str): Ruta al directorio raíz con las subcarpetas de imágenes.
        proporcion_entrenamiento (float): Proporción de imágenes para entrenamiento.

    Returns:
        dict: Diccionario con las rutas de las imágenes y etiquetas, organizadas en entrenamiento y prueba.
    """

    conjuntos_datos = {
        "entrenamiento": {"imagenes": [], "etiquetas": []},
        "prueba": {"imagenes": [], "etiquetas": []}
    }

    for persona in os.listdir(ruta_origen):
        ruta_persona = os.path.join(ruta_origen, persona)
        if os.path.isdir(ruta_persona):
            imagenes = [os.path.join(ruta_persona, img) for img in os.listdir(ruta_persona) if img.lower().endswith(('.png', '.jpg', '.jpeg'))]
            entrenamiento, prueba = train_test_split(imagenes, train_size=proporcion_entrenamiento, random_state=73)  # Semilla para reproducibilidad

            # Guardar datos de entrenamiento
            conjuntos_datos["entrenamiento"]["imagenes"].extend(entrenamiento)
            conjuntos_datos["entrenamiento"]["etiquetas"].extend([persona] * len(entrenamiento))

            # Guardar datos de prueba
            conjuntos_datos["prueba"]["imagenes"].extend(prueba)
            conjuntos_datos["prueba"]["etiquetas"].extend([persona] * len(prueba))

    return conjuntos_datos

# %%
# En la variable "ruta_origen" se encuentran las imagenes preprocesadas para enternamiento
datos_divididos = dividir_datos(ruta_origen)


# Acceder a los datos
lista_nombres_imagenes_entrenamiento = datos_divididos["entrenamiento"]["imagenes"]
lista_etiquetas_entrenamiento = datos_divididos["entrenamiento"]["etiquetas"]
lista_nombres_imagenes_prueba = datos_divididos["prueba"]["imagenes"]
lista_etiquetas_prueba = datos_divididos["prueba"]["etiquetas"]

# Estructura de datos_divididos:
# {
#     "entrenamiento": {
#         "imagenes": ["ruta/a/imagen1.jpg", "ruta/a/imagen2.png", ...],
#         "etiquetas": ["persona1", "persona1", ...]
#     },
#     "prueba": {
#         "imagenes": ["ruta/a/imagen5.jpg", "ruta/a/imagen6.png", ...],
#         "etiquetas": ["persona2", "persona2", ...]
#     }
# }

# %% [markdown]
# # ISOMAP

# %%
def precalcular_isomap(datos_entrenamiento, n_componentes_isomap=10, n_vecinos_isomap=5):
    """
    Precalcula las ubicaciones de Isomap para las imágenes de entrenamiento.

    Args:
        datos_entrenamiento (dict): Diccionario con rutas de imágenes y etiquetas de entrenamiento.
        n_componentes_isomap (int): Número de componentes para Isomap.
        n_vecinos_isomap (int): Número de vecinos para Isomap.

    Returns:
        tuple: (ubicaciones_isomap, etiquetas_entrenamiento)
    """

    # Cargar imágenes de entrenamiento
    imagenes_entrenamiento = []
    for ruta in datos_entrenamiento["imagenes"]:
        img = Image.open(ruta).convert('L')
        imagenes_entrenamiento.append(np.array(img).flatten())
    imagenes_entrenamiento = np.array(imagenes_entrenamiento)

    # Isomap
    isomap = Isomap(n_components=n_componentes_isomap, n_neighbors=n_vecinos_isomap)
    ubicaciones_isomap = isomap.fit_transform(imagenes_entrenamiento)

    return ubicaciones_isomap, datos_entrenamiento["etiquetas"], isomap

# %%
# Seteamos variable para manejo mas simple, incluye etiquetas
datos_entrenamiento = datos_divididos["entrenamiento"]

# %%
# Precalculamos datos
ubicaciones_isomap, etiquetas_entrenamiento, isomap_model = precalcular_isomap(datos_entrenamiento)

# %%
# Guardar datos precalculados
datos_guardar = {
    "ubicaciones_isomap": ubicaciones_isomap,
    "etiquetas_entrenamiento": etiquetas_entrenamiento,
    "n_componentes_isomap": 10,  # Guardar hiperparámetros
    "n_vecinos_isomap": 5,
    "isomap_model": isomap_model  # Store the fitted Isomap model
}

# %%
# Archivo parametros modelo

archivo_params = "/content/drive/MyDrive/datos_isomap.pkl"

with open(archivo_params, "wb") as f:
    pickle.dump(datos_guardar, f)

# %%
# Version nueva
def reconocer_cara_produccion(imagen_prueba, ruta_datos_precalculados=archivo_params):
    """
    Reconoce una cara usando datos precalculados de Isomap.

    Args:
        imagen_prueba (str): Ruta a la imagen de prueba.
        ruta_datos_precalculados (str): Ruta al archivo con los datos precalculados.

    Returns:
        list: Lista de las N etiquetas más cercanas y sus distancias.
    """

    # Cargar datos precalculados
    with open(ruta_datos_precalculados, "rb") as f:
        datos_cargados = pickle.load(f)

    ubicaciones_isomap = datos_cargados["ubicaciones_isomap"]
    etiquetas_entrenamiento = datos_cargados["etiquetas_entrenamiento"]
    # Get the pre-trained Isomap model
    isomap = datos_cargados["isomap_model"]

    # Cargar y mapear la imagen de prueba
    imagen_prueba_cargada = np.array(Image.open(imagen_prueba).convert('L')).flatten()

    # Transform the test image using the pre-trained model
    imagen_prueba_isomap = isomap.transform([imagen_prueba_cargada])

    # Calcular distancias y ranking
    distancias = euclidean_distances(imagen_prueba_isomap, ubicaciones_isomap)[0]
    indices_ordenados = np.argsort(distancias)[:3]
    ranking = [(etiquetas_entrenamiento[i], distancias[i]) for i in indices_ordenados]

    return ranking

# %%
# Ejemplo de uso en producción
imagen_prueba = datos_divididos["prueba"]["imagenes"][50]
print(datos_divididos["prueba"]["etiquetas"][50])
ranking = reconocer_cara_produccion(imagen_prueba)
print(ranking)
# Out:
# Mauricio
# [('Mauricio', np.float64(871.2282202464642)), ('Mauricio', np.float64(2400.977975380197)), ('Mauricio', np.float64(2862.2127745397192)), ('Mauricio', np.float64(2862.212774539722)), ('Mauricio', np.float64(4130.367088787949)), ('Mauricio', np.float64(4668.2972827933045)), ('Mauricio', np.float64(6177.613299640747)), ('José', np.float64(6434.254399807999)), ('Mauricio', np.float64(6573.955028137777)), ('José', np.float64(6690.849825896741)), ('José', np.float64(7847.270632749893)), ('José', np.float64(7995.576404384289)), ('Guadalupe', np.float64(8180.197631725395))]

# %%
def reconocer_cara_produccion2(imagen_prueba, ruta_datos_precalculados=archivo_params):
    """
    Reconoce una cara usando datos precalculados de Isomap.

    Args:
        imagen_prueba (str): Ruta a la imagen de prueba.
        ruta_datos_precalculados (str): Ruta al archivo con los datos precalculados.

    Returns:
        list: Lista de las 3 etiquetas más cercanas y distintas, con sus distancias.
    """

    # Cargar datos precalculados (same as before)
    with open(ruta_datos_precalculados, "rb") as f:
        datos_cargados = pickle.load(f)

    ubicaciones_isomap = datos_cargados["ubicaciones_isomap"]
    etiquetas_entrenamiento = datos_cargados["etiquetas_entrenamiento"]
    isomap = datos_cargados["isomap_model"]

    # Cargar y mapear la imagen de prueba (same as before)
    imagen_prueba_cargada = np.array(Image.open(imagen_prueba).convert('L')).flatten()
    imagen_prueba_isomap = isomap.transform([imagen_prueba_cargada])

    # Calcular distancias (same as before)
    distancias = euclidean_distances(imagen_prueba_isomap, ubicaciones_isomap)[0]
    indices_ordenados = np.argsort(distancias)

    # Obtener las 3 etiquetas distintas más cercanas
    ranking_01 = []
    etiquetas_encontradas = set()  # Use a set to track distinct labels
    for i in indices_ordenados:
        etiqueta = etiquetas_entrenamiento[i]
        if etiqueta not in etiquetas_encontradas:
            ranking_01.append((etiqueta, distancias[i]))
            etiquetas_encontradas.add(etiqueta)
            if len(ranking_01) == 3:
                break

    return ranking

# %%
print(ranking[0][0])
# Out:
# Noelia M

# %%
# Ejemplo de uso en producción
imagen_prueba = datos_divididos["prueba"]["imagenes"][67]
print(f'Etiqueta: {datos_divididos["prueba"]["etiquetas"][67]}')
ranking = reconocer_cara_produccion2(imagen_prueba)
for i in range(len(ranking)):
  print(f"Candidato {i+1}: {ranking[i][0]} - Indice: {ranking[i][1]} ")
# Out:
# Etiqueta: Cristian
# Candidato 1: Cristian - Indice: 1715.9601663120566
# Candidato 2: Alejandro - Indice: 3359.0499217868232
# Candidato 3: Daniel - Indice: 4354.524365185596

# %%
softmax

# %%
procesar_archivos_en_carpetas(ruta_entrada, ruta_salida, img_size)

para cada archivo (imagen)
  para hp1 de 1 a 100
    para hp2 de 1 a 15
      isomap(imagen)
      softmax(imagen)
      error(imagen)
      registrar_HPS_error_minimo()
